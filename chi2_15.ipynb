# %% [markdown]
# <a href="https://colab.research.google.com/github/Hemasri20/programming-java/blob/master/chi2_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Importing Libraries***

# %%
import numpy as np
import sys
np.set_printoptions(threshold=10)
import matplotlib.pyplot as plt
import pandas as pd 
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # ***Load the dataset***

# %%
#dataset=pd.read_csv('/content/drive/MyDrive/Ovarian_Cancer_Project-main/Ovarian_Cancer_Project-main/ovariantotal.csv')
df=pd.read_csv('/content/drive/MyDrive/Ovarian_Cancer_Project-main/Ovarian_Cancer_Project-main/ovariantotal.csv')
df.head()
# Out:
#      AFP     AG  Age   ALB  ALP  ALT  AST  BASO#  BASO%   BUN  ...   PCT  \
# 0   3.58  19.36   47  45.4   56   11   24   0.01   0.30  5.35  ...  0.09
# 1  34.24  23.98   61  39.9   95    9   13   0.02   0.30  3.21  ...  0.30
# 2   1.50  18.40   39  45.4   77    9   18   0.03   0.60  3.80  ...  0.13
# 3   2.75  16.60   45  39.2   26   16   17   0.05   0.74  5.27  ...  0.25
# 4   2.36  19.97   45  35.0   47   21   27   0.01   0.10  4.89  ...  0.28
#
#     PDW  PHOS  PLT   RBC   RDW  TBIL    TP     UA  TYPE
# 0  13.4  1.46   74  2.64  13.7   5.5  73.9  396.4     0
# 1  11.2  1.09  304  4.89  12.7   6.8  72.0  119.2     0
# 2  15.2  0.97  112  4.62  12.0  14.8  77.9  209.2     0
# 3  17.4  1.25  339  4.01  14.6  10.9  66.1  215.6     0
# 4  11.9  0.94  272  4.40  13.4   5.3  66.5  206.0     0
#
# [5 rows x 50 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.drop(labels=['TYPE'], axis=1),
    df['TYPE'],
    test_size=0.2,
    random_state=1)

# %%
X_train.head() 
X_train.shape
# Out:
# (279, 49)

# %%
X_test.head()
X_test.shape
# Out:
# (70, 49)

# %%
y_train.head()  
y_train.shape
# Out:
# (279,)

# %%
y_test.shape
# Out:
# (70,)

# %%
rs = np.random.RandomState(0)
df = pd.DataFrame(rs.rand(49,49))
corr = pd.DataFrame(df).corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_29651_row0_col0, #T_29651_row1_col1, #T_29651_row2_col2, #T_29651_row3_col3, #T_29651_row4_col4, #T_29651_row5_col5, #T_29651_row6_col6, #T_29651_row7_col7, #T_29651_row8_col8, #T_29651_row9_col9, #T_29651_row10_col10, #T_29651_row11_col11, #T_29651_row12_col12, #T_29651_row13_col13, #T_29651_row14_col14, #T_29651_row15_col15, #T_29651_row16_col16, #T_29651_row17_col17, #T_29651_row18_col18, #T_29651_row19_col19, #T_29651_row20_col20, #T_29651_row21_col21, #T_29651_row22_col22, #T_29651_row23_col23, #T_29651_row24_col24, #T_29651_row25_col25, #T_29651_row26_col26, #T_29651_row27_col27, #T_29651_row28_col28, #T_29651_row29_col29, #T_29651_row30_col30, #T_29651_row31_col31, #T_29651_row32_col32, #T_29651_row33_col33, #T_29651_row34_col34, #T_29651_row35_col35, #T_29651_row36_col36, #T_29651_row37_col37, #T_29651_row38_col38, #T_29651_row39_col39, #T_29651_row40_col40, #T_29651_row41_col41, #T_29651_row42_col42, #T_29651_row43_col43, #T_29651_row44_col44, #T_29651_row45_col45, #T_29651_row46_col46, #T_29651_row47_col47, #T_29651_row48_col48 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_29651_row0_col1, #T_29651_row0_col34, #T_29651_row0_col44, #T_29651_row2_col24, #T_29651_row12_col22, #T_29651_row13_col2, #T_29651_row13_col37, #T_29651_row21_col23, #T_29651_row23_col7, #T_29651_row24_col36, #T_29651_row28_col46, #T_29651_row29_col21, #T_29651_row31_col28, #T_29651_row36_col29, #T_29651_row40_col11, #T_29651_row41_col18, #T_29651_row43_col10, #T_29651_row43_col45, #T_29651_row44_col22, #T_29651_row45_col8, #T_29651_row45_col32, #T_29651_row47_col23, #T_29651_row48_col39 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_29651_row0_col2, #T_29651_row0_col21, #T_29651_row2_col40, #T_29651_row4_col48, #T_29651_row6_col26, #T_29651_row9_col30, #T_29651_row11_col46, #T_29651_row16_col29, #T_29651_row28_col27, #T_29651_row30_col15, #T_29651_row34_col9, #T_29651_row34_col31, #T_29651_row34_col41, #T_29651_row35_col1, #T_29651_row36_col20, #T_29651_row37_col1, #T_29651_row43_col15, #T_29651_row44_col43, #T_29651_row47_col16, #T_29651_row47_col36 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_29651_row0_col3, #T_29651_row2_col32, #T_29651_row15_col6, #T_29651_row15_col37, #T_29651_row21_col33, #T_29651_row24_col42, #T_29651_row33_col2, #T_29651_row37_col12, #T_29651_row38_col32, #T_29651_row43_col27 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_29651_row0_col4, #T_29651_row0_col15, #T_29651_row2_col6, #T_29651_row8_col30, #T_29651_row9_col20, #T_29651_row11_col44, #T_29651_row12_col2, #T_29651_row15_col29, #T_29651_row16_col40, #T_29651_row17_col35, #T_29651_row17_col42, #T_29651_row18_col48, #T_29651_row20_col28, #T_29651_row25_col29, #T_29651_row33_col23, #T_29651_row42_col15 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_29651_row0_col5, #T_29651_row1_col2, #T_29651_row5_col38, #T_29651_row6_col0, #T_29651_row7_col9, #T_29651_row8_col7, #T_29651_row8_col47, #T_29651_row9_col2, #T_29651_row9_col41, #T_29651_row10_col32, #T_29651_row17_col48, #T_29651_row18_col15, #T_29651_row19_col14, #T_29651_row19_col28, #T_29651_row20_col8, #T_29651_row21_col11, #T_29651_row22_col30, #T_29651_row26_col20, #T_29651_row26_col24, #T_29651_row26_col31, #T_29651_row28_col7, #T_29651_row28_col11, #T_29651_row29_col39, #T_29651_row31_col17, #T_29651_row31_col45, #T_29651_row33_col16, #T_29651_row34_col21, #T_29651_row34_col36, #T_29651_row35_col9, #T_29651_row35_col30, #T_29651_row35_col34, #T_29651_row38_col5, #T_29651_row38_col15, #T_29651_row39_col8, #T_29651_row39_col42, #T_29651_row41_col9, #T_29651_row47_col30, #T_29651_row48_col29, #T_29651_row48_col41 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_29651_row0_col6, #T_29651_row0_col25, #T_29651_row0_col46, #T_29651_row1_col7, #T_29651_row4_col18, #T_29651_row5_col6, #T_29651_row6_col1, #T_29651_row6_col27, #T_29651_row8_col37, #T_29651_row11_col12, #T_29651_row12_col25, #T_29651_row13_col14, #T_29651_row14_col19, #T_29651_row18_col7, #T_29651_row18_col12, #T_29651_row18_col28, #T_29651_row21_col0, #T_29651_row22_col21, #T_29651_row22_col29, #T_29651_row26_col48, #T_29651_row29_col43, #T_29651_row31_col11, #T_29651_row32_col10, #T_29651_row32_col18, #T_29651_row33_col1, #T_29651_row41_col20, #T_29651_row41_col26, #T_29651_row44_col19, #T_29651_row45_col46, #T_29651_row48_col27 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_29651_row0_col7, #T_29651_row2_col9, #T_29651_row9_col15, #T_29651_row15_col9, #T_29651_row23_col14, #T_29651_row32_col3, #T_29651_row45_col26, #T_29651_row48_col43 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_29651_row0_col8, #T_29651_row1_col48, #T_29651_row2_col16, #T_29651_row2_col41, #T_29651_row7_col10, #T_29651_row7_col44, #T_29651_row10_col31, #T_29651_row12_col34, #T_29651_row13_col42, #T_29651_row17_col27, #T_29651_row18_col10, #T_29651_row18_col39, #T_29651_row20_col33, #T_29651_row21_col37, #T_29651_row21_col45, #T_29651_row22_col27, #T_29651_row23_col9, #T_29651_row25_col28, #T_29651_row26_col36, #T_29651_row26_col40, #T_29651_row26_col44, #T_29651_row31_col10, #T_29651_row32_col19, #T_29651_row32_col44, #T_29651_row34_col17, #T_29651_row34_col19, #T_29651_row36_col16, #T_29651_row37_col23, #T_29651_row38_col29, #T_29651_row42_col28, #T_29651_row44_col18, #T_29651_row48_col1 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_29651_row0_col9, #T_29651_row2_col5, #T_29651_row2_col26, #T_29651_row7_col30, #T_29651_row8_col24, #T_29651_row8_col45, #T_29651_row9_col13, #T_29651_row9_col28, #T_29651_row13_col10, #T_29651_row15_col4, #T_29651_row15_col5, #T_29651_row15_col12, #T_29651_row15_col21, #T_29651_row18_col22, #T_29651_row19_col12, #T_29651_row19_col27, #T_29651_row19_col48, #T_29651_row20_col6, #T_29651_row21_col13, #T_29651_row21_col14, #T_29651_row26_col27, #T_29651_row27_col16, #T_29651_row27_col26, #T_29651_row29_col33, #T_29651_row30_col29, #T_29651_row31_col0, #T_29651_row34_col38, #T_29651_row37_col40, #T_29651_row38_col37, #T_29651_row40_col38, #T_29651_row41_col11, #T_29651_row41_col45, #T_29651_row45_col15, #T_29651_row47_col41 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_29651_row0_col10, #T_29651_row5_col42, #T_29651_row9_col42, #T_29651_row11_col24, #T_29651_row19_col23, #T_29651_row23_col40, #T_29651_row43_col48, #T_29651_row44_col25 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_29651_row0_col11, #T_29651_row2_col28, #T_29651_row6_col28, #T_29651_row7_col12, #T_29651_row8_col43, #T_29651_row9_col21, #T_29651_row10_col13, #T_29651_row12_col8, #T_29651_row14_col31, #T_29651_row17_col26, #T_29651_row19_col30, #T_29651_row20_col4, #T_29651_row24_col1, #T_29651_row24_col2, #T_29651_row28_col38, #T_29651_row34_col12, #T_29651_row34_col20, #T_29651_row36_col46, #T_29651_row37_col4, #T_29651_row37_col18, #T_29651_row37_col24, #T_29651_row38_col19, #T_29651_row39_col0, #T_29651_row39_col26, #T_29651_row40_col1, #T_29651_row44_col12, #T_29651_row45_col44, #T_29651_row46_col12, #T_29651_row47_col40 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_29651_row0_col12, #T_29651_row0_col47, #T_29651_row2_col19, #T_29651_row5_col26, #T_29651_row5_col48, #T_29651_row9_col7, #T_29651_row10_col1, #T_29651_row10_col48, #T_29651_row13_col3, #T_29651_row13_col9, #T_29651_row14_col42, #T_29651_row15_col22, #T_29651_row17_col15, #T_29651_row17_col19, #T_29651_row18_col41, #T_29651_row20_col3, #T_29651_row20_col11, #T_29651_row21_col8, #T_29651_row21_col47, #T_29651_row24_col38, #T_29651_row25_col13, #T_29651_row26_col5, #T_29651_row27_col22, #T_29651_row29_col30, #T_29651_row30_col28, #T_29651_row32_col41, #T_29651_row37_col38, #T_29651_row39_col27, #T_29651_row39_col34, #T_29651_row40_col30 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_29651_row0_col13, #T_29651_row4_col2, #T_29651_row5_col7, #T_29651_row15_col48, #T_29651_row36_col8, #T_29651_row45_col20, #T_29651_row46_col38 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_29651_row0_col14, #T_29651_row1_col13, #T_29651_row1_col

# %%
from sklearn.feature_selection import mutual_info_classif
# determine the mutual information
mutual_info = mutual_info_classif(X_train, y_train)
mutual_info
# Out:
# array([0.07248318, 0.        , 0.17677492, ..., 0.03508123, 0.01594311,
#        0.        ])

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index = X_train.columns
mutual_info.sort_values(ascending=False)
# Out:
# HE4          0.352804
# NEU          0.249215
# CA125        0.225010
# Age          0.176775
# LYM%         0.106365
# Menopause    0.094417
# CEA          0.093949
# ALB          0.086259
# Na           0.085385
# AFP          0.072483
# ALP          0.053693
# PLT          0.053089
# CA19-9       0.050980
# HGB          0.048364
# CL           0.044368
# PDW          0.040698
# PCT          0.038835
# CO2CP        0.038001
# GLO          0.036964
# GLU.         0.036611
# TBIL         0.035081
# MONO#        0.034559
# Ca           0.029286
# ALT          0.023715
# BASO%        0.021349
# Mg           0.019194
# TP           0.015943
# CA72-4       0.011743
# MONO%        0.011190
# GGT          0.010475
# IBIL         0.005861
# PHOS         0.000000
# RDW          0.000000
# MPV          0.000000
# RBC          0.000000
# HCT          0.000000
# MCV          0.000000
# MCH          0.000000
# LYM#         0.000000
# K            0.000000
# AG           0.000000
# EO%          0.000000
# EO#          0.000000
# DBIL         0.000000
# CREA         0.000000
# BUN          0.000000
# BASO#        0.000000
# AST          0.000000
# UA           0.000000
# dtype: float64

# %%
mutual_info.sort_values(ascending=False).plot.bar(figsize=(20, 8))
# Out:
# <AxesSubplot:>

# %%
from sklearn.feature_selection import SelectKBest
#No we Will select the  top 5 important features
sel_five_cols = SelectKBest(mutual_info_classif, k=15)
sel_five_cols.fit(X_train, y_train)
X_train.columns[sel_five_cols.get_support()]
# Out:
# Index(['AFP', 'Age', 'ALB', 'ALP', 'CA125', 'CA72-4', 'CEA', 'GLO', 'HE4',
#        'LYM%', 'Menopause', 'MONO#', 'Na', 'NEU', 'PLT'],
#       dtype='object')

# %%
X_train=X_train[['AFP', 'Age', 'ALB', 'ALP', 'CA125', 'CA72-4', 'CEA', 'GLO', 'HE4',
       'LYM%', 'Menopause', 'MONO#', 'Na', 'NEU', 'PLT']]

# %%
X_test=X_test[['AFP', 'Age', 'ALB', 'ALP', 'CA125', 'CA72-4', 'CEA', 'GLO', 'HE4',
       'LYM%', 'Menopause', 'MONO#', 'Na', 'NEU', 'PLT']] 
X_test.head()
# Out:
#       AFP  Age   ALB  ALP    CA125  CA72-4   CEA   GLO      HE4  LYM%  \
# 192  2.28   30  41.6   62    29.85    1.56  1.54  24.6    36.81  16.3
# 256  1.92   44  43.1   78    21.94   10.17  1.20  29.3    46.58  39.0
# 169  5.03   42  39.1  763  2154.00   10.17  0.80  26.2  1309.00  17.4
# 67   4.50   69  31.6   63  2741.00   10.17  0.55  32.4   183.94  16.1
# 201  0.84   20  32.6   66    43.41   10.17  0.59  31.1    56.91  37.5
#
#      Menopause  MONO#     Na   NEU  PLT
# 192          0   0.60  142.3  76.0  272
# 256          0   0.39  141.7  50.3  299
# 169          0   0.30  140.5  77.7  284
# 67           1   0.48  145.2  76.8  309
# 201          0   0.49  139.1  49.1  340

# %%
rs = np.random.RandomState(0)
df = pd.DataFrame(rs.rand(10, 10))
corr = pd.DataFrame(X_train).corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_54777_row0_col0, #T_54777_row1_col1, #T_54777_row2_col2, #T_54777_row3_col3, #T_54777_row4_col4, #T_54777_row5_col5, #T_54777_row6_col6, #T_54777_row7_col7, #T_54777_row8_col8, #T_54777_row9_col9, #T_54777_row10_col10, #T_54777_row11_col11, #T_54777_row12_col12, #T_54777_row13_col13, #T_54777_row14_col14 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_54777_row0_col1, #T_54777_row12_col11 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_54777_row0_col2 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_54777_row0_col3, #T_54777_row10_col7, #T_54777_row11_col7 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_54777_row0_col4, #T_54777_row6_col14, #T_54777_row7_col2, #T_54777_row8_col3, #T_54777_row12_col3, #T_54777_row12_col8 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_54777_row0_col5, #T_54777_row7_col0 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_54777_row0_col6, #T_54777_row0_col10, #T_54777_row4_col2, #T_54777_row7_col12 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_54777_row0_col7 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_54777_row0_col8, #T_54777_row5_col1 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_54777_row0_col9, #T_54777_row10_col11 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_54777_row0_col11 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_54777_row0_col12 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_54777_row0_col13, #T_54777_row9_col2 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_54777_row0_col14, #T_54777_row2_col12 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_54777_row1_col0, #T_54777_row14_col6 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_54777_row1_col2 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_54777_row1_col3 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_54777_row1_col4 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_54777_row1_col5, #T_54777_row5_col3, #T_54777_row6_col1, #T_54777_row7_col10, #T_54777_row14_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_54777_row1_col6, #T_54777_row4_col6 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_54777_row1_col7, #T_54777_row8_col0, #T_54777_row12_col5 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_54777_row1_col8, #T_54777_row3_col13 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_54777_row1_col9, #T_54777_row14_col7 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_54777_row1_col10 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_54777_row1_col11 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_54777_row1_col12 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_54777_row1_col13, #T_54777_row4_col8, #T_54777_row8_col13 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_54777_row1_col14, #T_54777_row5_col14 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_54777_row2_col0, #T_54777_row2_col1, #T_54777_row2_col4, #T_54777_row2_col6, #T_54777_row2_col8, #T_54777_row2_col11, #T_54777_row2_col14, #T_54777_row9_col0, #T_54777_row9_col1, #T_54777_row9_col3, #T_54777_row9_col5, #T_54777_row9_col10, #T_54777_row9_col13, #T_54777_row11_col2, #T_54777_row11_col12, #T_54777_row12_col0, #T_54777_row13_col7, #T_54777_row13_col9 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_54777_row2_col3 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_54777_row2_col5 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_54777_row2_col7, #T_54777_row8_col2, #T_54777_row12_col6 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_54777_row2_col9 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_54777_row2_col10 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_54777_row2_col13, #T_54777_row7_col1, #T_54777_row8_col9, #T_54777_row13_col5, #T_54777_row14_col10 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_54777_row3_col0, #T_54777_row5_col0 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_54777_row3_col1, #T_54777_row4_col14, #T_54777_row8_col1 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_54777_row3_col2, #T_54777_row6_col8, #T_54777_row11_col9, #T_54777_row14_col5 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_54777_row3_col4, #T_54777_row3_col11, #T_54777_row4_col9, #T_54777_row6_col11, #T_54777_row14_col9 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_54777_row3_col5 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_54777_row3_col6, #T_54777_row3_col8 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_54777_row3_col7 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_54777_row3_col9 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_54777_row3_col10, #T_54777_row6_col13, #T_54777_row7_col9 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_54777_row3_col12, #T_54777_row7_col4 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_54777_row3_col14, #T_54777_row4_col11 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_54777_row4_col0 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_54777_row4_col1 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_54777_row4_col3, #T_54777_row6_col5 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_54777_row4_col5, #T_54777_row14_col11 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_54777_row4_col7, #T_54777_row5_col12, #T_54777_row6_col0 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_54777_row4_col10, #T_54777_row11_col8 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_54777_row4_col12 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_54777_row4_col13 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_54777_row5_col2 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_54777_row5_col4 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_54777_row5_col6 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_54777_row5_col7 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_54777_row5_col8, #T_54777_row13_col14 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_54777_row5_col9, #T_54777_row8_col5 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_54777_row5_col10, #T_54777_row11_col4 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_54777_row5_col11, #T_54777_row10_col9 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_54777_row5_col13 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_54777_row6_col2, #T_54777_row6_col4 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_54777_row6_col3 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_54777_row6_col7 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_54777_row6_col9 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_54777_row6_col10, #T_54777_row10_col2 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_54777_row6_col12 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_54777_row7_col3, #T_54777_row12_col10 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_54777_row7_col5, #T_54777_row11_col5 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_54777_row7_col6, #T_54777_row13_col6 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_54777_row7_col8 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_54777_row7_col11, #T_54777_row10_col12, #T_54777_row14_col1 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_54777_row7_col13, #T_54777_row13_col4 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_54777_row7_col14, #T_54777_row8_col11 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_54777_row8_col4 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_54777_row8_col6, #T_54777_row8_col7 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_54777_row8_col10 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_54777_row8_col12, #T_54777_row10_col6 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_54777_row8_col14, #T_54777_row10_col8, #T_54777_row13_col8 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_54777_row9_col4 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_54777_row9_col6, #T_54777_row10_col0, #T_54777_row13_col2 {
#   background

# %% [markdown]
# # ***Feature Scaling***

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

print(X_train)
# Out:
# [[-0.11385783 -1.20381935  1.08000972 ...  0.69027578  0.00619545
#   -0.06542422]
#  [-0.11046472  0.70077634 -0.55058326 ...  1.63379575  1.88440908
#    0.85127312]
#  [-0.10839115  1.88293918 -2.27176474 ... -0.83387187  1.42305748
#   -0.07549782]
#  ...
#  [-0.10980494  0.37239777  0.08353623 ...  0.32738348  0.78741749
#   -0.09564501]
#  [-0.11470611  0.43807349  0.35530173 ... -1.8499703  -0.68890763
#   -0.41800012]
#  [-0.10744862  1.94861489 -0.45999476 ...  1.12574653 -0.93496182
#   -1.5764638 ]]

# %%
print(X_test)
# Out:
# [[-1.04998033e-01 -1.00679221e+00  1.01653933e-01 ...  6.53986549e-01
#    9.71958135e-01  1.76342109e-01]
#  [-1.08391147e-01 -8.73322209e-02  3.73419431e-01 ...  4.36251170e-01
#   -1.66287212e+00  4.48329233e-01]
#  [-7.90784109e-02 -2.18683648e-01 -3.51288563e-01 ...  7.80413542e-04
#    1.14624652e+00  2.97225275e-01]
#  ...
#  [-1.06694590e-01  1.29185776e+00  1.37889333e-01 ...  5.45118859e-01
#    6.19545041e-03 -7.54978196e-02]
#  [-1.09050919e-01  5.69424912e-01 -1.43835055e+00 ...  2.43215880e+00
#   -2.07296243e+00  4.58402830e-01]
#  [-1.11312996e-01 -4.15710788e-01  6.99538027e-01 ... -2.16954965e-01
#    6.19545041e-03 -3.07190554e-01]]

# %% [markdown]
# # ***RANDOM FORESTS***

# %%
from sklearn.ensemble import RandomForestClassifier
from numpy import round
rf = RandomForestClassifier(n_estimators = 500, random_state = 42)
rf.fit(X_train, y_train);

# %%
predictions = rf.predict(X_test)
errors = abs(predictions - y_test)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')
# Out:
# Mean Absolute Error: 0.1 degrees.

# %%
for i in range(len(predictions)):
  predictions[i]=round(predictions[i])

# %%
print(predictions)
# Out:
# [1 1 0 ... 1 0 1]

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
print('Accuracy:', accuracy_score(y_test,predictions))
# Out:
# Accuracy: 0.9

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89        32
#            1       0.90      0.92      0.91        38
#
#     accuracy                           0.90        70
#    macro avg       0.90      0.90      0.90        70
# weighted avg       0.90      0.90      0.90        70

# %%
from sklearn.metrics import classification_report,confusion_matrix
import seaborn as sns 
cm = confusion_matrix(y_test,predictions)
sns.heatmap(cm,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # ***Logistic Regression***

# %%
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression(random_state=0)

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred = classifier.predict(X_test)
print(y_pred)
# Out:
# [1 1 0 ... 0 0 1]

# %%
pred_proba= classifier.predict(X_test)
pred_proba
# Out:
# array([1, 1, 0, ..., 0, 0, 1])

# %%
Accuracy = classifier.score(X_test,y_test)
Accuracy
# Out:
# 0.8571428571428571

# %%
from sklearn.metrics import classification_report,confusion_matrix
import seaborn as sns 
cm = confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True)
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84        32
#            1       0.87      0.87      0.87        38
#
#     accuracy                           0.86        70
#    macro avg       0.86      0.86      0.86        70
# weighted avg       0.86      0.86      0.86        70

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
pred_prob = classifier.predict_proba(X_test)
fpr, tpr, thresh = roc_curve(y_test, pred_prob[:,1], pos_label=1)
auc_score = roc_auc_score(y_test, pred_prob[:,1])
auc_score
# Out:
# 0.915296052631579

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')

plt.plot(fpr, tpr, linestyle='--',color='green', label='Logistic Regression')

plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')

plt.legend(loc='best')
plt.savefig('ROC',dpi=300)
plt.show();

# %%
pip install sklearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sklearn
#   Downloading sklearn-0.0.post1.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2344 sha256=75a8ada9d511cd9bff34f7be79cfaf7089b82c326df99e30c46a686c7969b45c
#   Stored in directory: /root/.cache/pip/wheels/14/25/f7/1cc0956978ae479e75140219088deb7a36f60459df242b1a72
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0.post1

# %%
pip install sklearn.ensemble
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement sklearn.ensemble (from versions: none)
# ERROR: No matching distribution found for sklearn.ensemble

# %% [markdown]
# # ***ADABOOST***

# %%
from sklearn.ensemble import AdaBoostClassifier
classifier_Adaboost=AdaBoostClassifier()

# %%
params={ 'learning_rate': [1e-4, 1e-3, 1e-2, 1e-1, 1e0, 1e1, 1e2, 1e3], 
    
    "random_state": np.arange(0,100,1)}

# %%
from sklearn.model_selection import RandomizedSearchCV
random_search=RandomizedSearchCV(classifier_Adaboost,param_distributions=params,n_iter=5,scoring="roc_auc",n_jobs=-1,cv=5,verbose=3)

# %%
random_search.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# RandomizedSearchCV(cv=5, estimator=AdaBoostClassifier(), n_iter=5, n_jobs=-1,
#                    param_distributions={'learning_rate': [0.0001, 0.001, 0.01,
#                                                           0.1, 1.0, 10.0, 100.0,
#                                                           1000.0],
#                                         'random_state': array([ 0,  1,  2, ..., 97, 98, 99])},
#                    scoring='roc_auc', verbose=3)

# %%
random_search.best_estimator_
# Out:
# AdaBoostClassifier(random_state=58)

# %%
from sklearn.ensemble import AdaBoostClassifier
classifier_Adaboost=AdaBoostClassifier(learning_rate=0.1, random_state=3)
classifier_Adaboost.fit(X_train,y_train)
y_pred=classifier_Adaboost.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

cfm=confusion_matrix(y_test,y_pred)
print(cfm)

print("Classification Report: ")
print(classification_report(y_test,y_pred))

acc=accuracy_score(y_test,y_pred)
print("Accuracy of the model:",acc) 
print()
# Out:
# [[26  6]
#  [ 5 33]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.81      0.83        32
#            1       0.85      0.87      0.86        38
#
#     accuracy                           0.84        70
#    macro avg       0.84      0.84      0.84        70
# weighted avg       0.84      0.84      0.84        70
#
# Accuracy of the model: 0.8428571428571429

# %% [markdown]
# ### ***XGBOOST***

# %%
from xgboost import XGBClassifier
classifier_Xgboost=XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
              colsample_bynode=1, colsample_bytree=0.5, gamma=0.2, gpu_id=0,
              importance_type='gain', interaction_constraints='',
              learning_rate=0.1, max_delta_step=0, max_depth=10,
              min_child_weight=3,
              n_estimators=100, n_jobs=4, num_parallel_tree=1, random_state=0,
              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
              tree_method='exact', validate_parameters=1, verbosity=0)
classifier_Xgboost.fit(X_train, y_train)
y_pred=classifier_Xgboost.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

cfm=confusion_matrix(y_test,y_pred)
print(cfm)

print("Classification Report: ")
print(classification_report(y_test,y_pred))

acc=accuracy_score(y_test,y_pred)
print("Accuracy of the model:",acc)
# Out:
# [[29  3]
#  [ 5 33]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88        32
#            1       0.92      0.87      0.89        38
#
#     accuracy                           0.89        70
#    macro avg       0.88      0.89      0.89        70
# weighted avg       0.89      0.89      0.89        70
#
# Accuracy of the model: 0.8857142857142857

# %% [markdown]
# ## ***GRADIENT BOOSTING MACHINE***

# %%
from sklearn.ensemble import GradientBoostingClassifier 
from sklearn import metrics 
from sklearn.metrics import classification_report 
from sklearn.metrics import confusion_matrix

from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import make_scorer
from matplotlib import pyplot

# %%
baseline = GradientBoostingClassifier(learning_rate=0.1, n_estimators=100,max_depth=3, min_samples_split=2, min_samples_leaf=1, subsample=1,max_features='sqrt', random_state=42)

baseline.fit(X_train, y_train)

gbm_predict_train = baseline.predict(X_train)

#get accuracy
gbm_accuracy = metrics.accuracy_score(y_train, gbm_predict_train)

#print accuracy
print ("GBM training Accuracy: {0:.4f}".format(gbm_accuracy))

gbm_predict_test = baseline.predict(X_test)

#get accuracy
gbm_accuracy_testdata = metrics.accuracy_score(y_test, gbm_predict_test)

#print accuracy
print ("GBM testing Accuracy: {0:.4f}".format(gbm_accuracy_testdata))

from sklearn.metrics import log_loss
logloss = log_loss(y_test, gbm_predict_test)
print ("GBM Log Loss: {0:.4f}".format(logloss))

from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_test, gbm_predict_test)
print ("GBM AUC: {0:.4f}".format(auc))



#print('Training confusion matrix')
#print(confusion_matrix(y_train, gbm_predict_train))
#print('Testing confusion matrix')
#print(confusion_matrix(y_test, gbm_predict_test))

#print ("Confusion Matrix for GBM")

# labels for set 1=True to upper left and 0 = False to lower right
#print ("{0}".format(metrics.confusion_matrix(y_test, gbm_predict_test, labels=[1, 0])))

#print ("")

print ("Classification Report\n")

# labels for set 1=True to upper left and 0 = False to lower right
print ("{0}".format(metrics.classification_report(y_test, gbm_predict_test, labels=[1, 0])))
# Out:
# GBM training Accuracy: 1.0000
# GBM testing Accuracy: 0.8714
# GBM Log Loss: 4.6342
# GBM AUC: 0.8717
# Classification Report
#
#               precision    recall  f1-score   support
#
#            1       0.89      0.87      0.88        38
#            0       0.85      0.88      0.86        32
#
#     accuracy                           0.87        70
#    macro avg       0.87      0.87      0.87        70
# weighted avg       0.87      0.87      0.87        70

# %% [markdown]
# ## ***LIGHT GRADIENT BOOSTING***

# %%
import lightgbm as lgb
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
import sys,random
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import log_loss
import sklearn.metrics as metrics

# %%
params = {
    'application': 'binary', 
    'boosting': 'gbdt', 
    'num_iterations': 100, 
    'learning_rate': 0.05,
    'num_leaves': 62,
    'device': 'cpu', 
    'max_depth': -1, 
    'max_bin': 510, 
    'lambda_l1': 5, 
    'lambda_l2': 10, 
    'metric' : 'binary_error',
    'subsample_for_bin': 200, 
    'subsample': 1,
    'colsample_bytree': 0.8,
    'min_split_gain': 0.5, 
    'min_child_weight': 1, 
    'min_child_samples': 5
}

mdl = lgb.LGBMClassifier(boosting_type= 'gbdt', 
          objective = 'binary', 
          n_jobs = 5, 
          silent = True,
          max_depth = params['max_depth'],
          max_bin = params['max_bin'], 
          subsample_for_bin = params['subsample_for_bin'],
          subsample = params['subsample'], 
          min_split_gain = params['min_split_gain'], 
          min_child_weight = params['min_child_weight'], 
          min_child_samples = params['min_child_samples'])

mdl.get_params().keys()
# Out:
# dict_keys(['boosting_type', 'class_weight', 'colsample_bytree', 'importance_type', 'learning_rate', 'max_depth', 'min_child_samples', 'min_child_weight', 'min_split_gain', 'n_estimators', 'n_jobs', 'num_leaves', 'objective', 'random_state', 'reg_alpha', 'reg_lambda', 'silent', 'subsample', 'subsample_for_bin', 'subsample_freq', 'max_bin'])

# %%
gridParams = {
    'learning_rate': [0.005, 0.01],
    'n_estimators': [8,16,24],
    'num_leaves': [6,8,12,16],
    'boosting_type' : ['gbdt', 'dart'], 
    'objective' : ['binary'],
    'max_bin':[255, 510], 
    'random_state' : [500],
    'colsample_bytree' : [0.64, 0.65, 0.66],
    'subsample' : [0.7,0.75],
    'reg_alpha' : [1,1.2],
    'reg_lambda' : [1,1.2,1.4],
    }

grid = GridSearchCV(mdl, gridParams, verbose=1, cv=5, n_jobs=-1)
# Run the grid
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 3456 candidates, totalling 17280 fits

# %%
d_train = lgb.Dataset(X_train, label=y_train)
d_test = lgb.Dataset(X_test, label=y_test) 

watchlist = [d_train, d_test]

model = lgb.train(params, train_set=d_train, num_boost_round=1000, valid_sets=watchlist, early_stopping_rounds=50, verbose_eval=4)

y_t = model.predict(X_train)
y_t = np.where(y_t > 0.5, 1, 0)

train_acc = metrics.accuracy_score(y_train, y_t)

y_pred = model.predict(X_test)
y_pred = np.where(y_pred > 0.5, 1, 0)

test_acc = metrics.accuracy_score(y_test, y_pred)

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred)
logloss = log_loss(y_test, y_pred)

print ("Train accuracy: {0:.4f}".format(train_acc))
print ("Test accuracy: {0:.4f}".format(test_acc))
print ("Precision: {0:.4f}".format(precision))
print ("Recall: {0:.4f}".format(recall))
print ("F1: {0:.4f}".format(f1))
print ("AUC: {0:.4f}".format(auc))
print ("Log Loss: {0:.4f}".format(logloss)) 
print (metrics.classification_report(y_test, y_pred))
# Out:
# /usr/local/lib/python3.8/dist-packages/lightgbm/engine.py:118: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 50 rounds.
# [4]	training's binary_error: 0.0860215	valid_1's binary_error: 0.171429
# [8]	training's binary_error: 0.0860215	valid_1's binary_error: 0.171429
# [12]	training's binary_error: 0.0752688	valid_1's binary_error: 0.128571
# [16]	training's binary_error: 0.0752688	valid_1's binary_error: 0.128571
# [20]	training's binary_error: 0.0824373	valid_1's binary_error: 0.128571
# [24]	training's binary_error: 0.0752688	valid_1's binary_error: 0.128571
# [28]	training's binary_error: 0.0716846	valid_1's binary_error: 0.128571
# [32]	training's binary_error: 0.0716846	valid_1's binary_error: 0.128571
# [36]	training's binary_error: 0.0716846	valid_1's binary_error: 0.114286
# [40]	training's binary_error: 0.0716846	valid_1's binary_error: 0.114286
# [44]	training's binary_error: 0.0681004	valid_1's binary_error: 0.128571
# [48]	training's binary_error: 0.0645161	valid_1's binary_error: 0.114286
# [52]	training's binary_error: 0.0681004	valid_1's binary_error: 0.114286
# [56]	training's binary_error: 0.0681004	valid_1's binary_error: 0.114286
# [60]	training's binary_error: 0.0716846	valid_1's binary_error: 0.114286
# [64]	training's binary_error: 0.0752688	valid_1's binary_error: 0.114286
# [68]	training's binary_error: 0.0752688	valid_1's binary_error: 0.114286
# [72]	training's binary_error: 0.0752688	valid_1's binary_error: 0.114286
# [76]	training's binary_error: 0.0752688	valid_1's binary_error: 0.114286
# [80]	training's binary_error: 0.078853	valid_1's binary_error: 0.114286
# [84]	training's binary_error: 0.078853	valid_1's binary_error: 0.114286
# Early stopping, best iteration is:
# [35]	training's binary_error: 0.0716846	valid_1's binary_error: 0.114286
# Train accuracy: 0.9283
# Test accuracy: 0.8857
# Precision: 0.8750
# Recall: 0.9211
# F1: 0.8974
# AUC: 0.8824
# Log Loss: 4.1193
#               precision    recall  f1-score   support
#
#            0       0.90      0.84      0.87        32
#            1       0.88      0.92      0.90        38
#
#     accuracy                           0.89        70
#    macro avg       0.89      0.88      0.88        70
# weighted avg       0.89      0.89      0.89        70

# %% [markdown]
# # ***Voting Classifier***

# %% [markdown]
# ####Hard Voting

# %%
estimator = []
estimator.append(('LR', LogisticRegression(random_state=1)))
estimator.append(('GBC', GradientBoostingClassifier(learning_rate=0.1, n_estimators=100,max_depth=3, min_samples_split=2, min_samples_leaf=1, subsample=1,max_features='sqrt', random_state=42)))
estimator.append(('XGB', XGBClassifier()))
#estimator.append(('LGBM', lgb.LGBMClassifier())) 
#estimator.append(('ADB', AdaBoostClassifier()))
estimator.append(('RF', RandomForestClassifier(n_estimators = 1000, random_state = 42)))

# %%
from sklearn.ensemble import VotingClassifier
vot_hard = VotingClassifier(estimators = estimator, voting ='hard')
vot_hard.fit(X_train, y_train)
y_pred = vot_hard.predict(X_test)

# %%
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.8857142857142857

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88        32
#            1       0.92      0.87      0.89        38
#
#     accuracy                           0.89        70
#    macro avg       0.88      0.89      0.89        70
# weighted avg       0.89      0.89      0.89        70

# %%
cm = confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True)
# Out:
# <AxesSubplot:>

# %%
pip install vecstack
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting vecstack
#   Downloading vecstack-0.4.0.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from vecstack) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from vecstack) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.8/dist-packages (from vecstack) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.18->vecstack) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.18->vecstack) (1.2.0)
# Building wheels for collected packages: vecstack
#   Building wheel for vecstack (setup.py) ... done
#   Created wheel for vecstack: filename=vecstack-0.4.0-py3-none-any.whl size=19879 sha256=8a033f2dccf9ec78f06c9495f6731f7e55f1921a58d354385c0a26658cfeef29
#   Stored in directory: /root/.cache/pip/wheels/17/89/0b/21d5484cbf713c95b641ec1bdc40dd7ae798cbdea2337e3535
# Successfully built vecstack
# Installing collected packages: vecstack
# Successfully installed vecstack-0.4.0
