# %% [markdown]
# <a href="https://colab.research.google.com/github/Hemasri20/programming-java/blob/master/mutualinfo25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Importing Libraries***

# %%
import numpy as np
import sys
np.set_printoptions(threshold=10)
import matplotlib.pyplot as plt
import pandas as pd 
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # ***Load the dataset***

# %%
#dataset=pd.read_csv('/content/drive/MyDrive/Ovarian_Cancer_Project-main/Ovarian_Cancer_Project-main/ovariantotal.csv')
df=pd.read_csv('/content/drive/MyDrive/Ovarian_Cancer_Project-main/Ovarian_Cancer_Project-main/ovariantotal.csv')
df.head()
# Out:
#      AFP     AG  Age   ALB  ALP  ALT  AST  BASO#  BASO%   BUN  ...   PCT  \
# 0   3.58  19.36   47  45.4   56   11   24   0.01   0.30  5.35  ...  0.09
# 1  34.24  23.98   61  39.9   95    9   13   0.02   0.30  3.21  ...  0.30
# 2   1.50  18.40   39  45.4   77    9   18   0.03   0.60  3.80  ...  0.13
# 3   2.75  16.60   45  39.2   26   16   17   0.05   0.74  5.27  ...  0.25
# 4   2.36  19.97   45  35.0   47   21   27   0.01   0.10  4.89  ...  0.28
#
#     PDW  PHOS  PLT   RBC   RDW  TBIL    TP     UA  TYPE
# 0  13.4  1.46   74  2.64  13.7   5.5  73.9  396.4     0
# 1  11.2  1.09  304  4.89  12.7   6.8  72.0  119.2     0
# 2  15.2  0.97  112  4.62  12.0  14.8  77.9  209.2     0
# 3  17.4  1.25  339  4.01  14.6  10.9  66.1  215.6     0
# 4  11.9  0.94  272  4.40  13.4   5.3  66.5  206.0     0
#
# [5 rows x 50 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.drop(labels=['TYPE'], axis=1),
    df['TYPE'],
    test_size=0.2,
    random_state=1)

# %%
X_train.head() 
X_train.shape
# Out:
# (279, 49)

# %%
X_test.head()
X_test.shape
# Out:
# (70, 49)

# %%
y_train.head()  
y_train.shape
# Out:
# (279,)

# %%
y_test.shape
# Out:
# (70,)

# %%
rs = np.random.RandomState(0)
df = pd.DataFrame(rs.rand(49,49))
corr = pd.DataFrame(df).corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_0d2a6_row0_col0, #T_0d2a6_row1_col1, #T_0d2a6_row2_col2, #T_0d2a6_row3_col3, #T_0d2a6_row4_col4, #T_0d2a6_row5_col5, #T_0d2a6_row6_col6, #T_0d2a6_row7_col7, #T_0d2a6_row8_col8, #T_0d2a6_row9_col9, #T_0d2a6_row10_col10, #T_0d2a6_row11_col11, #T_0d2a6_row12_col12, #T_0d2a6_row13_col13, #T_0d2a6_row14_col14, #T_0d2a6_row15_col15, #T_0d2a6_row16_col16, #T_0d2a6_row17_col17, #T_0d2a6_row18_col18, #T_0d2a6_row19_col19, #T_0d2a6_row20_col20, #T_0d2a6_row21_col21, #T_0d2a6_row22_col22, #T_0d2a6_row23_col23, #T_0d2a6_row24_col24, #T_0d2a6_row25_col25, #T_0d2a6_row26_col26, #T_0d2a6_row27_col27, #T_0d2a6_row28_col28, #T_0d2a6_row29_col29, #T_0d2a6_row30_col30, #T_0d2a6_row31_col31, #T_0d2a6_row32_col32, #T_0d2a6_row33_col33, #T_0d2a6_row34_col34, #T_0d2a6_row35_col35, #T_0d2a6_row36_col36, #T_0d2a6_row37_col37, #T_0d2a6_row38_col38, #T_0d2a6_row39_col39, #T_0d2a6_row40_col40, #T_0d2a6_row41_col41, #T_0d2a6_row42_col42, #T_0d2a6_row43_col43, #T_0d2a6_row44_col44, #T_0d2a6_row45_col45, #T_0d2a6_row46_col46, #T_0d2a6_row47_col47, #T_0d2a6_row48_col48 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_0d2a6_row0_col1, #T_0d2a6_row0_col34, #T_0d2a6_row0_col44, #T_0d2a6_row2_col24, #T_0d2a6_row12_col22, #T_0d2a6_row13_col2, #T_0d2a6_row13_col37, #T_0d2a6_row21_col23, #T_0d2a6_row23_col7, #T_0d2a6_row24_col36, #T_0d2a6_row28_col46, #T_0d2a6_row29_col21, #T_0d2a6_row31_col28, #T_0d2a6_row36_col29, #T_0d2a6_row40_col11, #T_0d2a6_row41_col18, #T_0d2a6_row43_col10, #T_0d2a6_row43_col45, #T_0d2a6_row44_col22, #T_0d2a6_row45_col8, #T_0d2a6_row45_col32, #T_0d2a6_row47_col23, #T_0d2a6_row48_col39 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_0d2a6_row0_col2, #T_0d2a6_row0_col21, #T_0d2a6_row2_col40, #T_0d2a6_row4_col48, #T_0d2a6_row6_col26, #T_0d2a6_row9_col30, #T_0d2a6_row11_col46, #T_0d2a6_row16_col29, #T_0d2a6_row28_col27, #T_0d2a6_row30_col15, #T_0d2a6_row34_col9, #T_0d2a6_row34_col31, #T_0d2a6_row34_col41, #T_0d2a6_row35_col1, #T_0d2a6_row36_col20, #T_0d2a6_row37_col1, #T_0d2a6_row43_col15, #T_0d2a6_row44_col43, #T_0d2a6_row47_col16, #T_0d2a6_row47_col36 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_0d2a6_row0_col3, #T_0d2a6_row2_col32, #T_0d2a6_row15_col6, #T_0d2a6_row15_col37, #T_0d2a6_row21_col33, #T_0d2a6_row24_col42, #T_0d2a6_row33_col2, #T_0d2a6_row37_col12, #T_0d2a6_row38_col32, #T_0d2a6_row43_col27 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_0d2a6_row0_col4, #T_0d2a6_row0_col15, #T_0d2a6_row2_col6, #T_0d2a6_row8_col30, #T_0d2a6_row9_col20, #T_0d2a6_row11_col44, #T_0d2a6_row12_col2, #T_0d2a6_row15_col29, #T_0d2a6_row16_col40, #T_0d2a6_row17_col35, #T_0d2a6_row17_col42, #T_0d2a6_row18_col48, #T_0d2a6_row20_col28, #T_0d2a6_row25_col29, #T_0d2a6_row33_col23, #T_0d2a6_row42_col15 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_0d2a6_row0_col5, #T_0d2a6_row1_col2, #T_0d2a6_row5_col38, #T_0d2a6_row6_col0, #T_0d2a6_row7_col9, #T_0d2a6_row8_col7, #T_0d2a6_row8_col47, #T_0d2a6_row9_col2, #T_0d2a6_row9_col41, #T_0d2a6_row10_col32, #T_0d2a6_row17_col48, #T_0d2a6_row18_col15, #T_0d2a6_row19_col14, #T_0d2a6_row19_col28, #T_0d2a6_row20_col8, #T_0d2a6_row21_col11, #T_0d2a6_row22_col30, #T_0d2a6_row26_col20, #T_0d2a6_row26_col24, #T_0d2a6_row26_col31, #T_0d2a6_row28_col7, #T_0d2a6_row28_col11, #T_0d2a6_row29_col39, #T_0d2a6_row31_col17, #T_0d2a6_row31_col45, #T_0d2a6_row33_col16, #T_0d2a6_row34_col21, #T_0d2a6_row34_col36, #T_0d2a6_row35_col9, #T_0d2a6_row35_col30, #T_0d2a6_row35_col34, #T_0d2a6_row38_col5, #T_0d2a6_row38_col15, #T_0d2a6_row39_col8, #T_0d2a6_row39_col42, #T_0d2a6_row41_col9, #T_0d2a6_row47_col30, #T_0d2a6_row48_col29, #T_0d2a6_row48_col41 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_0d2a6_row0_col6, #T_0d2a6_row0_col25, #T_0d2a6_row0_col46, #T_0d2a6_row1_col7, #T_0d2a6_row4_col18, #T_0d2a6_row5_col6, #T_0d2a6_row6_col1, #T_0d2a6_row6_col27, #T_0d2a6_row8_col37, #T_0d2a6_row11_col12, #T_0d2a6_row12_col25, #T_0d2a6_row13_col14, #T_0d2a6_row14_col19, #T_0d2a6_row18_col7, #T_0d2a6_row18_col12, #T_0d2a6_row18_col28, #T_0d2a6_row21_col0, #T_0d2a6_row22_col21, #T_0d2a6_row22_col29, #T_0d2a6_row26_col48, #T_0d2a6_row29_col43, #T_0d2a6_row31_col11, #T_0d2a6_row32_col10, #T_0d2a6_row32_col18, #T_0d2a6_row33_col1, #T_0d2a6_row41_col20, #T_0d2a6_row41_col26, #T_0d2a6_row44_col19, #T_0d2a6_row45_col46, #T_0d2a6_row48_col27 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_0d2a6_row0_col7, #T_0d2a6_row2_col9, #T_0d2a6_row9_col15, #T_0d2a6_row15_col9, #T_0d2a6_row23_col14, #T_0d2a6_row32_col3, #T_0d2a6_row45_col26, #T_0d2a6_row48_col43 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_0d2a6_row0_col8, #T_0d2a6_row1_col48, #T_0d2a6_row2_col16, #T_0d2a6_row2_col41, #T_0d2a6_row7_col10, #T_0d2a6_row7_col44, #T_0d2a6_row10_col31, #T_0d2a6_row12_col34, #T_0d2a6_row13_col42, #T_0d2a6_row17_col27, #T_0d2a6_row18_col10, #T_0d2a6_row18_col39, #T_0d2a6_row20_col33, #T_0d2a6_row21_col37, #T_0d2a6_row21_col45, #T_0d2a6_row22_col27, #T_0d2a6_row23_col9, #T_0d2a6_row25_col28, #T_0d2a6_row26_col36, #T_0d2a6_row26_col40, #T_0d2a6_row26_col44, #T_0d2a6_row31_col10, #T_0d2a6_row32_col19, #T_0d2a6_row32_col44, #T_0d2a6_row34_col17, #T_0d2a6_row34_col19, #T_0d2a6_row36_col16, #T_0d2a6_row37_col23, #T_0d2a6_row38_col29, #T_0d2a6_row42_col28, #T_0d2a6_row44_col18, #T_0d2a6_row48_col1 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_0d2a6_row0_col9, #T_0d2a6_row2_col5, #T_0d2a6_row2_col26, #T_0d2a6_row7_col30, #T_0d2a6_row8_col24, #T_0d2a6_row8_col45, #T_0d2a6_row9_col13, #T_0d2a6_row9_col28, #T_0d2a6_row13_col10, #T_0d2a6_row15_col4, #T_0d2a6_row15_col5, #T_0d2a6_row15_col12, #T_0d2a6_row15_col21, #T_0d2a6_row18_col22, #T_0d2a6_row19_col12, #T_0d2a6_row19_col27, #T_0d2a6_row19_col48, #T_0d2a6_row20_col6, #T_0d2a6_row21_col13, #T_0d2a6_row21_col14, #T_0d2a6_row26_col27, #T_0d2a6_row27_col16, #T_0d2a6_row27_col26, #T_0d2a6_row29_col33, #T_0d2a6_row30_col29, #T_0d2a6_row31_col0, #T_0d2a6_row34_col38, #T_0d2a6_row37_col40, #T_0d2a6_row38_col37, #T_0d2a6_row40_col38, #T_0d2a6_row41_col11, #T_0d2a6_row41_col45, #T_0d2a6_row45_col15, #T_0d2a6_row47_col41 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_0d2a6_row0_col10, #T_0d2a6_row5_col42, #T_0d2a6_row9_col42, #T_0d2a6_row11_col24, #T_0d2a6_row19_col23, #T_0d2a6_row23_col40, #T_0d2a6_row43_col48, #T_0d2a6_row44_col25 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_0d2a6_row0_col11, #T_0d2a6_row2_col28, #T_0d2a6_row6_col28, #T_0d2a6_row7_col12, #T_0d2a6_row8_col43, #T_0d2a6_row9_col21, #T_0d2a6_row10_col13, #T_0d2a6_row12_col8, #T_0d2a6_row14_col31, #T_0d2a6_row17_col26, #T_0d2a6_row19_col30, #T_0d2a6_row20_col4, #T_0d2a6_row24_col1, #T_0d2a6_row24_col2, #T_0d2a6_row28_col38, #T_0d2a6_row34_col12, #T_0d2a6_row34_col20, #T_0d2a6_row36_col46, #T_0d2a6_row37_col4, #T_0d2a6_row37_col18, #T_0d2a6_row37_col24, #T_0d2a6_row38_col19, #T_0d2a6_row39_col0, #T_0d2a6_row39_col26, #T_0d2a6_row40_col1, #T_0d2a6_row44_col12, #T_0d2a6_row45_col44, #T_0d2a6_row46_col12, #T_0d2a6_row47_col40 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_0d2a6_row0_col12, #T_0d2a6_row0_col47, #T_0d2a6_row2_col19, #T_0d2a6_row5_col26, #T_0d2a6_row5_col48, #T_0d2a6_row9_col7, #T_0d2a6_row10_col1, #T_0d2a6_row10_col48, #T_0d2a6_row13_col3, #T_0d2a6_row13_col9, #T_0d2a6_row14_col42, #T_0d2a6_row15_col22, #T_0d2a6_row17_col15, #T_0d2a6_row17_col19, #T_0d2a6_row18_col41, #T_0d2a6_row20_col3, #T_0d2a6_row20_col11, #T_0d2a6_row21_col8, #T_0d2a6_row21_col47, #T_0d2a6_row24_col38, #T_0d2a6_row25_col13, #T_0d2a6_row26_col5, #T_0d2a6_row27_col22, #T_0d2a6_row29_col30, #T_0d2a6_row30_col28, #T_0d2a6_row32_col41, #T_0d2a6_row37_col38, #T_0d2a6_row39_col27, #T_0d2a6_row39_col34, #T_0d2a6_row40_col30 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_0d2a6_row0_col13, #T_0d2a6_row4_col2, #T_0d2a6_row5_col7, #T_0d2a6_row15_col48, #T_0d2a6_row36_col8, #T_0d2a6_row45_col20, #T_0d2a6_row46_col38 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_0d2a6_row0_col14, #T_0d2a6_row1_col13, #T_0d2a6_row1_col

# %%
from sklearn.feature_selection import mutual_info_classif
# determine the mutual information
mutual_info = mutual_info_classif(X_train, y_train)
mutual_info
# Out:
# array([0.07938765, 0.        , 0.16774918, ..., 0.03557498, 0.0262543 ,
#        0.        ])

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index = X_train.columns
mutual_info.sort_values(ascending=False)
# Out:
# HE4          0.352804
# NEU          0.246821
# CA125        0.225010
# Menopause    0.183085
# Age          0.167749
# LYM%         0.097117
# CEA          0.088289
# PLT          0.084820
# ALB          0.082823
# AFP          0.079388
# Na           0.077690
# ALP          0.065178
# PCT          0.055720
# CA19-9       0.053660
# MONO%        0.051573
# MONO#        0.050299
# CA72-4       0.044304
# PDW          0.040975
# ALT          0.040769
# CL           0.037545
# GLO          0.037156
# TBIL         0.035575
# HGB          0.030639
# TP           0.026254
# DBIL         0.026148
# CO2CP        0.021752
# GLU.         0.019557
# Mg           0.012089
# AST          0.008542
# BASO#        0.007439
# K            0.005853
# Ca           0.003388
# RDW          0.000000
# PHOS         0.000000
# MPV          0.000000
# RBC          0.000000
# HCT          0.000000
# MCV          0.000000
# MCH          0.000000
# LYM#         0.000000
# IBIL         0.000000
# AG           0.000000
# GGT          0.000000
# EO%          0.000000
# EO#          0.000000
# CREA         0.000000
# BUN          0.000000
# BASO%        0.000000
# UA           0.000000
# dtype: float64

# %%
mutual_info.sort_values(ascending=False).plot.bar(figsize=(20, 8))
# Out:
# <AxesSubplot:>

# %%
from sklearn.feature_selection import SelectKBest
#No we Will select the  top 5 important features
sel_five_cols = SelectKBest(mutual_info_classif, k=15)
sel_five_cols.fit(X_train, y_train)
X_train.columns[sel_five_cols.get_support()]
# Out:
# Index(['AFP', 'Age', 'ALB', 'ALP', 'CA125', 'CA19-9', 'CEA', 'HE4', 'LYM%',
#        'Menopause', 'Na', 'NEU', 'PCT', 'PDW', 'PLT'],
#       dtype='object')

# %%
X_train=X_train[['HE4', 'NEU', 'CA125', 'Age', 'CEA', 'LYM%', 'Menopause', 'Na', 'ALB', 'PLT', 'ALP', 'MONO#', 'AFP', 'CA19-9', 'CL','RDW','MCH','MONO%','GLO','PCT','TBIL','PDW','CA72-4','TP','HGB']]

# %%
X_test=X_test[['HE4', 'NEU', 'CA125', 'Age', 'CEA', 'LYM%', 'Menopause', 'Na', 'ALB', 'PLT', 'ALP', 'MONO#', 'AFP', 'CA19-9', 'CL','RDW','MCH','MONO%','GLO','PCT','TBIL','PDW','CA72-4','TP','HGB']]

X_test.head()
# Out:
#          HE4   NEU    CA125  Age   CEA  LYM%  Menopause     Na   ALB  PLT  \
# 192    36.81  76.0    29.85   30  1.54  16.3          0  142.3  41.6  272
# 256    46.58  50.3    21.94   44  1.20  39.0          0  141.7  43.1  299
# 169  1309.00  77.7  2154.00   42  0.80  17.4          0  140.5  39.1  284
# 67    183.94  76.8  2741.00   69  0.55  16.1          1  145.2  31.6  309
# 201    56.91  49.1    43.41   20  0.59  37.5          0  139.1  32.6  340
#
#      ...   RDW   MCH  MONO%   GLO    PCT  TBIL   PDW  CA72-4    TP    HGB
# 192  ...  15.8  29.1   6.24  24.6  0.184  12.2  16.5    1.56  66.2  118.0
# 256  ...  13.2  28.1   4.90  29.3  0.340  17.7  13.5   10.17  72.4  128.0
# 169  ...  15.0  27.1   4.30  26.2  0.320  14.6  14.5   10.17  65.3  147.0
# 67   ...  12.3  28.5   6.30  32.4  0.320   5.2  11.5   10.17  64.0  125.0
# 201  ...  13.3  24.0   8.10  31.1  0.360   2.7  12.3   10.17  63.7  109.0
#
# [5 rows x 25 columns]

# %%
rs = np.random.RandomState(0)
df = pd.DataFrame(rs.rand(10, 10))
corr = pd.DataFrame(X_train).corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_a2833_row0_col0, #T_a2833_row1_col1, #T_a2833_row2_col2, #T_a2833_row3_col3, #T_a2833_row4_col4, #T_a2833_row5_col5, #T_a2833_row6_col6, #T_a2833_row7_col7, #T_a2833_row8_col8, #T_a2833_row9_col9, #T_a2833_row10_col10, #T_a2833_row11_col11, #T_a2833_row12_col12, #T_a2833_row13_col13, #T_a2833_row14_col14, #T_a2833_row15_col15, #T_a2833_row16_col16, #T_a2833_row17_col17, #T_a2833_row18_col18, #T_a2833_row19_col19, #T_a2833_row20_col20, #T_a2833_row21_col21, #T_a2833_row22_col22, #T_a2833_row23_col23, #T_a2833_row24_col24 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a2833_row0_col1, #T_a2833_row2_col0, #T_a2833_row3_col1, #T_a2833_row18_col23 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_a2833_row0_col2 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_a2833_row0_col3, #T_a2833_row2_col9, #T_a2833_row10_col3, #T_a2833_row14_col7, #T_a2833_row24_col23 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_a2833_row0_col4, #T_a2833_row2_col23, #T_a2833_row8_col10, #T_a2833_row12_col22, #T_a2833_row19_col8, #T_a2833_row20_col18 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_a2833_row0_col5, #T_a2833_row1_col10, #T_a2833_row1_col22, #T_a2833_row5_col14, #T_a2833_row6_col15, #T_a2833_row8_col1, #T_a2833_row9_col6, #T_a2833_row12_col24, #T_a2833_row17_col4, #T_a2833_row18_col3, #T_a2833_row22_col18 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_a2833_row0_col6, #T_a2833_row16_col1, #T_a2833_row20_col24 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_a2833_row0_col7, #T_a2833_row0_col13, #T_a2833_row11_col24, #T_a2833_row12_col10, #T_a2833_row12_col13, #T_a2833_row12_col23, #T_a2833_row16_col4, #T_a2833_row21_col12, #T_a2833_row24_col12, #T_a2833_row24_col13, #T_a2833_row24_col14 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_a2833_row0_col8 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_a2833_row0_col9, #T_a2833_row1_col0, #T_a2833_row6_col0 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_a2833_row0_col10, #T_a2833_row2_col18, #T_a2833_row7_col10, #T_a2833_row12_col0, #T_a2833_row18_col13, #T_a2833_row18_col17, #T_a2833_row22_col3, #T_a2833_row23_col1 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_a2833_row0_col11, #T_a2833_row8_col16, #T_a2833_row18_col9 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_a2833_row0_col12, #T_a2833_row0_col14, #T_a2833_row0_col24, #T_a2833_row3_col4, #T_a2833_row15_col4, #T_a2833_row16_col17, #T_a2833_row24_col3, #T_a2833_row24_col9 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_a2833_row0_col15, #T_a2833_row3_col11, #T_a2833_row5_col15, #T_a2833_row12_col16, #T_a2833_row14_col16, #T_a2833_row15_col9, #T_a2833_row19_col0 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_a2833_row0_col16, #T_a2833_row6_col5, #T_a2833_row7_col24, #T_a2833_row12_col19, #T_a2833_row13_col11, #T_a2833_row13_col18, #T_a2833_row19_col3, #T_a2833_row22_col11, #T_a2833_row22_col19 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_a2833_row0_col17, #T_a2833_row2_col10, #T_a2833_row2_col24, #T_a2833_row3_col18, #T_a2833_row5_col7, #T_a2833_row14_col3 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_a2833_row0_col18, #T_a2833_row7_col15, #T_a2833_row9_col12, #T_a2833_row13_col6, #T_a2833_row13_col17, #T_a2833_row20_col4 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_a2833_row0_col19, #T_a2833_row7_col1, #T_a2833_row10_col19, #T_a2833_row15_col1, #T_a2833_row23_col16 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_a2833_row0_col20, #T_a2833_row5_col10 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_a2833_row0_col21, #T_a2833_row10_col7, #T_a2833_row11_col2, #T_a2833_row18_col24, #T_a2833_row21_col17, #T_a2833_row22_col6 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_a2833_row0_col22, #T_a2833_row6_col7, #T_a2833_row19_col2, #T_a2833_row22_col5 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_a2833_row0_col23, #T_a2833_row1_col5, #T_a2833_row1_col17, #T_a2833_row1_col23, #T_a2833_row5_col1, #T_a2833_row5_col3, #T_a2833_row5_col6, #T_a2833_row5_col22, #T_a2833_row7_col13, #T_a2833_row8_col0, #T_a2833_row8_col2, #T_a2833_row8_col3, #T_a2833_row8_col9, #T_a2833_row8_col11, #T_a2833_row9_col14, #T_a2833_row9_col20, #T_a2833_row11_col8, #T_a2833_row14_col10, #T_a2833_row14_col12, #T_a2833_row14_col18, #T_a2833_row15_col7, #T_a2833_row15_col16, #T_a2833_row15_col24, #T_a2833_row16_col15, #T_a2833_row18_col14, #T_a2833_row19_col21, #T_a2833_row21_col19, #T_a2833_row23_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a2833_row1_col2, #T_a2833_row7_col16, #T_a2833_row12_col15, #T_a2833_row18_col1 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_a2833_row1_col3, #T_a2833_row1_col11, #T_a2833_row6_col2, #T_a2833_row19_col11, #T_a2833_row20_col5 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_a2833_row1_col4, #T_a2833_row1_col20, #T_a2833_row17_col10, #T_a2833_row18_col4 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_a2833_row1_col6, #T_a2833_row13_col5 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_a2833_row1_col7, #T_a2833_row2_col8, #T_a2833_row3_col12, #T_a2833_row3_col23, #T_a2833_row5_col4, #T_a2833_row12_col6, #T_a2833_row19_col4, #T_a2833_row21_col6, #T_a2833_row24_col22 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_a2833_row1_col8, #T_a2833_row19_col20 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_a2833_row1_col9, #T_a2833_row15_col5, #T_a2833_row20_col16, #T_a2833_row22_col0 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_a2833_row1_col12, #T_a2833_row3_col14, #T_a2833_row7_col19, #T_a2833_row13_col3, #T_a2833_row13_col9, #T_a2833_row13_col19 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_a2833_row1_col13, #T_a2833_row16_col7, #T_a2833_row18_col21, #T_a2833_row22_col17 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_a2833_row1_col14, #T_a2833_row7_col17, #T_a2833_row16_col18, #T_a2833_row17_col8, #T_a2833_row17_col23, #T_a2833_row21_col13 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_a2833_row1_col15, #T_a2833_row4_col17, #T_a2833_row12_col11, #T_a2833_row15_col0, #T_a2833_row21_col0 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_a2833_row1_col16, #T_a2833_row3_col9, #T_a2833_row3_col15, #T_a2833_row4_col16, #T_a2833_row10_col16, #T_a2833_row22_col9, #T_a2833_row22_col16 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_a2833_row1_col18, #T_a2833_row4_col14, #T_a2833_row7_col11, #T_a2833_row12_col3, #T_a2833_row17_col6, #T_a2833_row22_col20, #T_a2833_row23_col9 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_a2833_row1_col19 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_a2833_row1_col21, #T_a2833_row9_col23, #T_a2833_row13_col12, #T_a2833_row24_col15 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_a2833_row1_col24, #T_a2833_row10_col21, #T_a2833_row13_col20, #T_a2833_row13_col22, #T_a2833_row14_col11, #T_a2833_row17_col13, #T_a2833_row22_col7, #T_a2833_row24_col6 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_a2833_row2_col1 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_a2833_row2_col3, #T_a2833_row5_col23 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_a2833_row2_col4, #T_a2833_row4_col12, #T_a2833_row12_col4, #T_a2833_row15_col14, #T_a2833_row16_col2, #T_a2833_row19_col17, #T_a2833_row20_col13, #T_a2833_row21_col3, #T_a2833_row24_col11 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_a2833_row2_col5, #T_a2833_row4_col11, #T_a2833_row9_col5, #T_a2833_row10_col2, #T_a2833_row10_col11, #T_a2833_row16_col20, #T_a2833_row19_col5, #T_a2833_row21_col11 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_a2833_row2_col6, #T_a2833_row11_col0, #T_a2833_row16_col5, #T_a2833_row17_col15 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_a2833_row2_col7, #T_a2833_row7_col18, #T_a2833_row14_col20, #T_a2833_row15_col8, #T_a2833_row19_col23 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_a2833_row2_col11, #T_a2833_row3_col19, #T_a2833_row10_col9 {
#   background-color: #bfd3f6;
#   co

# %% [markdown]
# # ***Feature Scaling***

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

print(X_train)
# Out:
# [[-0.37412506  0.00619545 -0.40205538 ... -0.00612426  0.93395688
#    0.36546244]
#  [ 0.07758872  1.88440908  0.04230901 ... -0.00612426 -0.51697453
#   -0.12454307]
#  [ 2.19757598  1.42305748  0.6597819  ... -0.00612426 -2.15426411
#   -0.18579376]
#  ...
#  [-0.00701354  0.78741749 -0.35036748 ... -0.00612426  0.98720207
#   -0.92080202]
#  [-0.35276688 -0.68890763 -0.39440527 ... -0.31348993  0.21514683
#   -0.12454307]
#  [ 2.0820913  -0.93496182  1.14846971 ... -0.00612426 -0.53028583
#    0.73296658]]

# %%
print(X_test)
# Out:
# [[-0.39548323  0.97195813 -0.40409209 ... -0.56444038 -0.62346491
#   -0.43079651]
#  [-0.37012851 -1.66287212 -0.41391553 ... -0.00612426  0.20183553
#    0.18171038]
#  [ 2.90605501  1.14624652  2.23389068 ... -0.00612426 -0.74326658
#    1.34547347]
#  ...
#  [-0.33667688  0.00619545 -0.41515743 ... -0.00612426 -0.22412599
#    0.30421175]
#  [-0.01365715 -2.07296243 -0.39700084 ... -0.00612426 -0.55690842
#   -0.24704445]
#  [-0.40428083  0.00619545 -0.38347655 ... -0.00612426 -0.30399377
#    0.18171038]]

# %% [markdown]
# # ***RANDOM FORESTS***

# %%
import pandas as pd 
import re
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import chi2_contingency

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %matplotlib inline

# %%
rfc=RandomForestClassifier(random_state=42)

param_grid = { 
    'n_estimators': [200, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['gini', 'entropy']
}

CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 5)
CV_rfc.fit(X_train, y_train)

m_best = CV_rfc.best_estimator_

y_t = m_best.predict(X_train)
train_acc = accuracy_score(y_train, y_t)

y_pred = m_best.predict(X_test)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(

# %%
test_acc = accuracy_score(y_test, y_pred)


print('Training confusion matrix')
print(confusion_matrix(y_train, y_t))
print('Testing confusion matrix')
print(confusion_matrix(y_test, y_pred)) 
print ("Train accuracy: {0:.4f}".format(train_acc))
print ("Test accuracy: {0:.4f}".format(test_acc))

'''print ("Feature Importance")

importances = m_best.feature_importances_
for i in importances:
    print(i)'''
    
pred_prob3 = m_best.predict_proba(X_test) 
print(classification_report(y_test,y_pred))
# Out:
# Training confusion matrix
# [[129  10]
#  [  0 140]]
# Testing confusion matrix
# [[28  4]
#  [ 3 35]]
# Train accuracy: 0.9642
# Test accuracy: 0.9000
#               precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89        32
#            1       0.90      0.92      0.91        38
#
#     accuracy                           0.90        70
#    macro avg       0.90      0.90      0.90        70
# weighted avg       0.90      0.90      0.90        70

# %% [markdown]
# # ***Logistic Regression***

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression

grid_values = {'penalty': ['l1','l2'], 'C': [0.001,0.01,0.1,1,10,100,1000]}
lr=LogisticRegression(random_state=42)
model_lr = GridSearchCV(lr, param_grid=grid_values)

model_lr.fit(X_train,y_train)

m_best = model_lr.best_estimator_

y_t = m_best.predict(X_train)
train_acc = accuracy_score(y_train, y_t)

y_pred = m_best.predict(X_test) 
print(y_pred) 



test_acc = accuracy_score(y_test, y_pred)



print('Training confusion matrix')
print(confusion_matrix(y_train, y_t))
print('Testing confusion matrix')
print(confusion_matrix(y_test, y_pred))


    
pred_prob5 = m_best.predict_proba(X_test)  
print(classification_report(y_test,y_pred))
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [1 1 0 ... 1 0 1]
# Training confusion matrix
# [[122  17]
#  [  4 136]]
# Testing confusion matrix
# [[25  7]
#  [ 4 34]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.78      0.82        32
#            1       0.83      0.89      0.86        38
#
#     accuracy                           0.84        70
#    macro avg       0.85      0.84      0.84        70
# weighted avg       0.84      0.84      0.84        70
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 35 fits failed out of a total of 70.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 35 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the test scores are non-finite: [       nan 0.82811688        nan ... 0.86409091        nan 0.86409091]
#   warnings.warn(

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
pred_prob = m_best.predict_proba(X_test)
fpr, tpr, thresh = roc_curve(y_test, pred_prob[:,1], pos_label=1)
auc_score = roc_auc_score(y_test, pred_prob[:,1])
auc_score
# Out:
# 0.9177631578947368

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')

plt.plot(fpr, tpr, linestyle='--',color='green', label='Logistic Regression')

plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')

plt.legend(loc='best')
plt.savefig('ROC',dpi=300)
plt.show();

# %%
pip install sklearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sklearn
#   Downloading sklearn-0.0.post1.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2344 sha256=75a8ada9d511cd9bff34f7be79cfaf7089b82c326df99e30c46a686c7969b45c
#   Stored in directory: /root/.cache/pip/wheels/14/25/f7/1cc0956978ae479e75140219088deb7a36f60459df242b1a72
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0.post1

# %%
pip install sklearn.ensemble
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement sklearn.ensemble (from versions: none)
# ERROR: No matching distribution found for sklearn.ensemble

# %% [markdown]
# # ***ADABOOST***

# %%
from sklearn.ensemble import AdaBoostClassifier
classifier_Adaboost=AdaBoostClassifier()

# %%
params={ 'learning_rate': [1e-4, 1e-3, 1e-2, 1e-1, 1e0, 1e1, 1e2, 1e3], 
    
    "random_state": np.arange(0,100,1)}

# %%
from sklearn.model_selection import RandomizedSearchCV
random_search=RandomizedSearchCV(classifier_Adaboost,param_distributions=params,n_iter=5,scoring="roc_auc",n_jobs=-1,cv=5,verbose=3)

# %%
random_search.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# RandomizedSearchCV(cv=5, estimator=AdaBoostClassifier(), n_iter=5, n_jobs=-1,
#                    param_distributions={'learning_rate': [0.0001, 0.001, 0.01,
#                                                           0.1, 1.0, 10.0, 100.0,
#                                                           1000.0],
#                                         'random_state': array([ 0,  1,  2, ..., 97, 98, 99])},
#                    scoring='roc_auc', verbose=3)

# %%
random_search.best_estimator_
# Out:
# AdaBoostClassifier(learning_rate=0.1, random_state=27)

# %%
from sklearn.ensemble import AdaBoostClassifier
classifier_Adaboost=AdaBoostClassifier(learning_rate=0.1, random_state=3)
classifier_Adaboost.fit(X_train,y_train)
y_pred=classifier_Adaboost.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

cfm=confusion_matrix(y_test,y_pred)
print(cfm)

print("Classification Report: ")
print(classification_report(y_test,y_pred))

acc=accuracy_score(y_test,y_pred)
print("Accuracy of the model:",acc) 
print()
# Out:
# [[29  3]
#  [ 4 34]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.89        32
#            1       0.92      0.89      0.91        38
#
#     accuracy                           0.90        70
#    macro avg       0.90      0.90      0.90        70
# weighted avg       0.90      0.90      0.90        70
#
# Accuracy of the model: 0.9

# %% [markdown]
# ### ***XGBOOST***

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV 
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

estimator = XGBClassifier(
    objective= 'binary:logistic',
    nthread=4,
    seed=42
)

parameters = {
    'max_depth': range (2, 10, 1),
    'n_estimators': range(60, 220, 40),
    'learning_rate': [0.1, 0.01, 0.05]
}

grid_search = GridSearchCV(
    estimator=estimator,
    param_grid=parameters,
    scoring = 'roc_auc',
    n_jobs = 10,
    cv = 4,
    verbose=True
)

grid_search.fit(X_train, y_train)

grid_search.best_estimator_

m_best = grid_search.best_estimator_

y_t = m_best.predict(X_train)
train_acc = accuracy_score(y_train, y_t)

y_pred = m_best.predict(X_test)

test_acc = accuracy_score(y_test, y_pred)
'''precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred)
logloss = log_loss(y_test, y_pred)

print ("Train accuracy: {0:.4f}".format(train_acc))
print ("Test accuracy: {0:.4f}".format(test_acc))
print ("Precision: {0:.4f}".format(precision))
print ("Recall: {0:.4f}".format(recall))
print ("F1: {0:.4f}".format(f1))
print ("AUC: {0:.4f}".format(auc))
print ("Log Loss: {0:.4f}".format(logloss)) 
'''

print('Training confusion matrix')
print(confusion_matrix(y_train, y_t))
print('Testing confusion matrix')
print(confusion_matrix(y_test, y_pred))

print ("Feature Importance")

importances = m_best.feature_importances_
for i in importances:
    print(i)

pred_prob2 = m_best.predict_proba(X_test) 

cfm=confusion_matrix(y_test,y_pred)
print(cfm)

print("Classification Report: ")
print(classification_report(y_test,y_pred))
# Out:
# Fitting 4 folds for each of 96 candidates, totalling 384 fits
# Training confusion matrix
# [[139   0]
#  [  0 140]]
# Testing confusion matrix
# [[29  3]
#  [ 4 34]]
# Feature Importance
# 0.33983567
# 0.04938589
# 0.028988715
# 0.022677787
# 0.09925017
# 0.025802953
# 0.0
# 0.027582368
# 0.020735694
# 0.018629165
# 0.015348941
# 0.0
# 0.022122514
# 0.031982362
# 0.026806643
# 0.019031195
# 0.016759427
# 0.019779488
# 0.064872056
# 0.03513432
# 0.012201508
# 0.024491439
# 0.023486016
# 0.02946342
# 0.025632294
# [[29  3]
#  [ 4 34]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.89        32
#            1       0.92      0.89      0.91        38
#
#     accuracy                           0.90        70
#    macro avg       0.90      0.90      0.90        70
# weighted avg       0.90      0.90      0.90        70

# %% [markdown]
# ## ***GRADIENT BOOSTING MACHINE***

# %%
from sklearn.ensemble import GradientBoostingClassifier 
from sklearn import metrics 
from sklearn.metrics import classification_report 
from sklearn.metrics import confusion_matrix

from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import make_scorer
from matplotlib import pyplot

# %%
baseline = GradientBoostingClassifier(learning_rate=0.1, n_estimators=100,max_depth=3, min_samples_split=2, min_samples_leaf=1, subsample=1,max_features='sqrt', random_state=42)

baseline.fit(X_train, y_train)

gbm_predict_train = baseline.predict(X_train)

#get accuracy
gbm_accuracy = metrics.accuracy_score(y_train, gbm_predict_train)

#print accuracy
print ("GBM training Accuracy: {0:.4f}".format(gbm_accuracy))

gbm_predict_test = baseline.predict(X_test)

#get accuracy
gbm_accuracy_testdata = metrics.accuracy_score(y_test, gbm_predict_test)

#print accuracy
print ("GBM testing Accuracy: {0:.4f}".format(gbm_accuracy_testdata))

from sklearn.metrics import log_loss
logloss = log_loss(y_test, gbm_predict_test)
print ("GBM Log Loss: {0:.4f}".format(logloss))

from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_test, gbm_predict_test)
print ("GBM AUC: {0:.4f}".format(auc))



#print('Training confusion matrix')
#print(confusion_matrix(y_train, gbm_predict_train))
#print('Testing confusion matrix')
#print(confusion_matrix(y_test, gbm_predict_test))

#print ("Confusion Matrix for GBM")

# labels for set 1=True to upper left and 0 = False to lower right
#print ("{0}".format(metrics.confusion_matrix(y_test, gbm_predict_test, labels=[1, 0])))

#print ("")

print ("Classification Report\n")

# labels for set 1=True to upper left and 0 = False to lower right
print ("{0}".format(metrics.classification_report(y_test, gbm_predict_test, labels=[1, 0])))
# Out:
# GBM training Accuracy: 1.0000
# GBM testing Accuracy: 0.8571
# GBM Log Loss: 5.1491
# GBM AUC: 0.8586
# Classification Report
#
#               precision    recall  f1-score   support
#
#            1       0.89      0.84      0.86        38
#            0       0.82      0.88      0.85        32
#
#     accuracy                           0.86        70
#    macro avg       0.86      0.86      0.86        70
# weighted avg       0.86      0.86      0.86        70

# %% [markdown]
# ## ***LIGHT GRADIENT BOOSTING***

# %%
import lightgbm as lgb
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
import sys,random
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import log_loss
import sklearn.metrics as metrics

# %%
params = {
    'application': 'binary', 
    'boosting': 'gbdt', 
    'num_iterations': 100, 
    'learning_rate': 0.05,
    'num_leaves': 62,
    'device': 'cpu', 
    'max_depth': -1, 
    'max_bin': 510, 
    'lambda_l1': 5, 
    'lambda_l2': 10, 
    'metric' : 'binary_error',
    'subsample_for_bin': 200, 
    'subsample': 1,
    'colsample_bytree': 0.8,
    'min_split_gain': 0.5, 
    'min_child_weight': 1, 
    'min_child_samples': 5
}

mdl = lgb.LGBMClassifier(boosting_type= 'gbdt', 
          objective = 'binary', 
          n_jobs = 5, 
          silent = True,
          max_depth = params['max_depth'],
          max_bin = params['max_bin'], 
          subsample_for_bin = params['subsample_for_bin'],
          subsample = params['subsample'], 
          min_split_gain = params['min_split_gain'], 
          min_child_weight = params['min_child_weight'], 
          min_child_samples = params['min_child_samples'])

mdl.get_params().keys()
# Out:
# dict_keys(['boosting_type', 'class_weight', 'colsample_bytree', 'importance_type', 'learning_rate', 'max_depth', 'min_child_samples', 'min_child_weight', 'min_split_gain', 'n_estimators', 'n_jobs', 'num_leaves', 'objective', 'random_state', 'reg_alpha', 'reg_lambda', 'silent', 'subsample', 'subsample_for_bin', 'subsample_freq', 'max_bin'])

# %%
gridParams = {
    'learning_rate': [0.005, 0.01],
    'n_estimators': [8,16,24],
    'num_leaves': [6,8,12,16],
    'boosting_type' : ['gbdt', 'dart'], 
    'objective' : ['binary'],
    'max_bin':[255, 510], 
    'random_state' : [500],
    'colsample_bytree' : [0.64, 0.65, 0.66],
    'subsample' : [0.7,0.75],
    'reg_alpha' : [1,1.2],
    'reg_lambda' : [1,1.2,1.4],
    }

grid = GridSearchCV(mdl, gridParams, verbose=1, cv=5, n_jobs=-1)
# Run the grid
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 3456 candidates, totalling 17280 fits
# GridSearchCV(cv=5,
#              estimator=LGBMClassifier(max_bin=510, min_child_samples=5,
#                                       min_child_weight=1, min_split_gain=0.5,
#                                       n_jobs=5, objective='binary', subsample=1,
#                                       subsample_for_bin=200),
#              n_jobs=-1,
#              param_grid={'boosting_type': ['gbdt', 'dart'],
#                          'colsample_bytree': [0.64, 0.65, 0.66],
#                          'learning_rate': [0.005, 0.01], 'max_bin': [255, 510],
#                          'n_estimators': [8, 16, 24],
#                          'num_leaves': [6, 8, 12, 16], 'objective': ['binary'],
#                          'random_state': [500], 'reg_alpha': [1, 1.2],
#                          'reg_lambda': [1, 1.2, 1.4],
#                          'subsample': [0.7, 0.75]},
#              verbose=1)

# %%
d_train = lgb.Dataset(X_train, label=y_train)
d_test = lgb.Dataset(X_test, label=y_test) 

watchlist = [d_train, d_test]

model = lgb.train(params, train_set=d_train, num_boost_round=1000, valid_sets=watchlist, early_stopping_rounds=50, verbose_eval=4)

y_t = model.predict(X_train)
y_t = np.where(y_t > 0.5, 1, 0)

train_acc = metrics.accuracy_score(y_train, y_t)

y_pred = model.predict(X_test)
y_pred = np.where(y_pred > 0.5, 1, 0)

test_acc = metrics.accuracy_score(y_test, y_pred)

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred)
logloss = log_loss(y_test, y_pred)

print ("Train accuracy: {0:.4f}".format(train_acc))
print ("Test accuracy: {0:.4f}".format(test_acc))
print ("Precision: {0:.4f}".format(precision))
print ("Recall: {0:.4f}".format(recall))
print ("F1: {0:.4f}".format(f1))
print ("AUC: {0:.4f}".format(auc))
print ("Log Loss: {0:.4f}".format(logloss)) 
print (metrics.classification_report(y_test, y_pred))
# Out:
# /usr/local/lib/python3.8/dist-packages/lightgbm/engine.py:118: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 50 rounds.
# [4]	training's binary_error: 0.0896057	valid_1's binary_error: 0.128571
# [8]	training's binary_error: 0.0896057	valid_1's binary_error: 0.128571
# [12]	training's binary_error: 0.0896057	valid_1's binary_error: 0.128571
# [16]	training's binary_error: 0.0716846	valid_1's binary_error: 0.128571
# [20]	training's binary_error: 0.0645161	valid_1's binary_error: 0.128571
# [24]	training's binary_error: 0.0645161	valid_1's binary_error: 0.128571
# [28]	training's binary_error: 0.0681004	valid_1's binary_error: 0.128571
# [32]	training's binary_error: 0.0645161	valid_1's binary_error: 0.128571
# [36]	training's binary_error: 0.0645161	valid_1's binary_error: 0.128571
# [40]	training's binary_error: 0.0645161	valid_1's binary_error: 0.128571
# [44]	training's binary_error: 0.0645161	valid_1's binary_error: 0.128571
# [48]	training's binary_error: 0.0645161	valid_1's binary_error: 0.128571
# [52]	training's binary_error: 0.0681004	valid_1's binary_error: 0.128571
# Early stopping, best iteration is:
# [3]	training's binary_error: 0.0896057	valid_1's binary_error: 0.128571
# Train accuracy: 0.9104
# Test accuracy: 0.8714
# Precision: 0.8537
# Recall: 0.9211
# F1: 0.8861
# AUC: 0.8668
# Log Loss: 4.6342
#               precision    recall  f1-score   support
#
#            0       0.90      0.81      0.85        32
#            1       0.85      0.92      0.89        38
#
#     accuracy                           0.87        70
#    macro avg       0.88      0.87      0.87        70
# weighted avg       0.87      0.87      0.87        70

# %% [markdown]
# # ***Voting Classifier***

# %% [markdown]
# ####Hard Voting

# %%
estimator = []
estimator.append(('LR', LogisticRegression(random_state=1)))
estimator.append(('GBC', GradientBoostingClassifier(learning_rate=0.1, n_estimators=100,max_depth=3, min_samples_split=2, min_samples_leaf=1, subsample=1,max_features='sqrt', random_state=42)))
estimator.append(('XGB', XGBClassifier()))
estimator.append(('LGBM', lgb.LGBMClassifier())) 
#estimator.append(('ADB', AdaBoostClassifier()))
estimator.append(('RF', RandomForestClassifier(n_estimators = 1000, random_state = 42)))

# %%
from sklearn.ensemble import VotingClassifier
vot_hard = VotingClassifier(estimators = estimator, voting ='hard')
vot_hard.fit(X_train, y_train)
y_pred = vot_hard.predict(X_test)

# %%
print(metrics.accuracy_score(y_test,y_pred)) 
print(metrics.precision_score(y_test,y_pred)) 
print(metrics.f1_score(y_test, y_pred))
# Out:
# 0.8857142857142857
# 0.8947368421052632
# 0.8947368421052632

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88        32
#            1       0.89      0.89      0.89        38
#
#     accuracy                           0.89        70
#    macro avg       0.88      0.88      0.88        70
# weighted avg       0.89      0.89      0.89        70

# %%
cm = confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True)
# Out:
# <AxesSubplot:>

# %%
pip install vecstack
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting vecstack
#   Downloading vecstack-0.4.0.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from vecstack) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from vecstack) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.8/dist-packages (from vecstack) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.18->vecstack) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.18->vecstack) (1.2.0)
# Building wheels for collected packages: vecstack
#   Building wheel for vecstack (setup.py) ... done
#   Created wheel for vecstack: filename=vecstack-0.4.0-py3-none-any.whl size=19879 sha256=8a033f2dccf9ec78f06c9495f6731f7e55f1921a58d354385c0a26658cfeef29
#   Stored in directory: /root/.cache/pip/wheels/17/89/0b/21d5484cbf713c95b641ec1bdc40dd7ae798cbdea2337e3535
# Successfully built vecstack
# Installing collected packages: vecstack
# Successfully installed vecstack-0.4.0
